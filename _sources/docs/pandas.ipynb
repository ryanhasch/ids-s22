# %% [markdown]
# (pandas)=
#
# # Data Manipulation with Pandas
#
# From [`pandas` documentation](https://pandas.pydata.org/pandas-docs/stable/getting_started/overview.html):
#
# > pandas is a Python package providing fast, flexible, and expressive
# > data structures designed to make working with “relational” or
# > “labeled” data both easy and intuitive. It aims to be the
# > fundamental high-level building block for doing practical,
# > real-world data analysis in Python. Additionally, it has the broader
# > goal of becoming the most powerful and flexible open source data
# > analysis/manipulation tool available in any language. It is already
# > well on its way toward this goal.
#
# > pandas is well suited for many different kinds of data:
# >
# > + Tabular data with heterogeneously-typed columns, as in an SQL
# >   table or Excel spreadsheet
# > + Ordered and unordered (not necessarily fixed-frequency) time
# >   series data
# > + Arbitrary matrix data (homogeneously typed or heterogeneous) with
# >   row and column labels
# > + Any other form of observational / statistical data sets. The data
# >   need not be labeled at all to be placed into a pandas data
# >   structure
#
# ## Import/Export

# %%
import pandas as pd

nyc_crash = pd.read_csv("../data/nyc_mv_collisions_202201.csv")
nyc_crash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7659 entries, 0 to 7658
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CRASH DATE                     7659 non-null   object
#  1   CRASH TIME                     7659 non-null   object
#  2   BOROUGH                        5025 non-null   object
#  3   ZIP CODE                       5025 non-null   float64
#  4   LATITUDE                       7097 non-null   float64
#  5   LONGITUDE                      7097 non-null   float64
#  6   LOCATION                       7097 non-null   object
#  7   ON STREET NAME                 5625 non-null   object
#  8   CROSS STREET NAME              3620 non-null   object
#  9   OFF STREET NAME                2034 non-null   object
#  10  NUMBER OF PERSONS INJURED      7659 non-null   int64
#  11  NUMBER OF PERSONS KILLED       7659 non-null   int64
#  12  NUMBER OF PEDESTRIANS INJURED  7659 non-null   int64
#  13  NUMBER OF PEDESTRIANS KILLED   7659 non-null   int64
#  14  NUMBER OF CYCLIST INJURED      7659 non-null   int64
#  15  NUMBER OF CYCLIST KILLED       7659 non-null   int64
#  16  NUMBER OF MOTORIST INJURED     7659 non-null   int64
#  17  NUMBER OF MOTORIST KILLED      7659 non-null   int64
#  18  CONTRIBUTING FACTOR VEHICLE 1  7615 non-null   object
#  19  CONTRIBUTING FACTOR VEHICLE 2  5624 non-null   object
#  20  CONTRIBUTING FACTOR VEHICLE 3  824 non-null    object
#  21  CONTRIBUTING FACTOR VEHICLE 4  225 non-null    object
#  22  CONTRIBUTING FACTOR VEHICLE 5  80 non-null     object
#  23  COLLISION_ID                   7659 non-null   int64
#  24  VEHICLE TYPE CODE 1            7539 non-null   object
#  25  VEHICLE TYPE CODE 2            4748 non-null   object
#  26  VEHICLE TYPE CODE 3            752 non-null    object
#  27  VEHICLE TYPE CODE 4            207 non-null    object
#  28  VEHICLE TYPE CODE 5            78 non-null     object
# dtypes: float64(3), int64(9), object(17)
# memory usage: 1.7+ MB

# %% [markdown]
# Exporting data out of pandas is provided by different `to_*`methods.

# %%
nyc_crash.to_csv("my_nyc.csv", index=False)

# %% [markdown]
# ## View and Description
#
# The `head/tail/info` methods and the `dtypes` attribute are convenient
# for a first check.
#
#
# Descriptive statistics for numeric variables:

# %%
nyc_crash_desc = nyc_crash.describe()
nyc_crash_desc
# Out:
#            ZIP CODE     LATITUDE    LONGITUDE  NUMBER OF PERSONS INJURED  \
# count   5025.000000  7097.000000  7097.000000                7659.000000
# mean   10908.957015    40.609463   -73.705503                   0.404753
# std      514.740028     2.160598     3.919451                   0.726622
# min    10000.000000     0.000000   -74.249980                   0.000000
# 25%    10459.000000    40.665085   -73.960370                   0.000000
# 50%    11209.000000    40.712505   -73.917310                   0.000000
# 75%    11354.000000    40.786957   -73.862274                   1.000000
# max    11697.000000    40.909206     0.000000                   8.000000
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count               7659.000000                    7659.000000
# mean                   0.002350                       0.084345
# std                    0.048425                       0.290332
# min                    0.000000                       0.000000
# 25%                    0.000000                       0.000000
# 50%                    0.000000                       0.000000
# 75%                    0.000000                       0.000000
# max                    1.000000                       3.000000
#
#        NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# count                   7659.000000                7659.000000
# mean                       0.001306                   0.021935
# std                        0.036113                   0.149131
# min                        0.000000                   0.000000
# 25%                        0.000000                   0.000000
# 50%                        0.000000                   0.000000
# 75%                        0.000000                   0.000000
# max                        1.000000                   2.000000
#
#        NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# count                    7659.0                 7659.000000
# mean                        0.0                    0.287505
# std                         0.0                    0.692545
# min                         0.0                    0.000000
# 25%                         0.0                    0.000000
# 50%                         0.0                    0.000000
# 75%                         0.0                    0.000000
# max                         0.0                    8.000000
#
#        NUMBER OF MOTORIST KILLED  COLLISION_ID
# count                7659.000000  7.659000e+03
# mean                    0.000914  4.495510e+06
# std                     0.030220  2.338111e+03
# min                     0.000000  4.491064e+06
# 25%                     0.000000  4.493532e+06
# 50%                     0.000000  4.495533e+06
# 75%                     0.000000  4.497480e+06
# max                     1.000000  4.500594e+06

# %% [markdown]
# Transpose the data:

# %%
nyc_crash_desc.T
# Out:
#                                 count          mean          std  \
# ZIP CODE                       5025.0  1.090896e+04   514.740028
# LATITUDE                       7097.0  4.060946e+01     2.160598
# LONGITUDE                      7097.0 -7.370550e+01     3.919451
# NUMBER OF PERSONS INJURED      7659.0  4.047526e-01     0.726622
# NUMBER OF PERSONS KILLED       7659.0  2.350176e-03     0.048425
# NUMBER OF PEDESTRIANS INJURED  7659.0  8.434521e-02     0.290332
# NUMBER OF PEDESTRIANS KILLED   7659.0  1.305653e-03     0.036113
# NUMBER OF CYCLIST INJURED      7659.0  2.193498e-02     0.149131
# NUMBER OF CYCLIST KILLED       7659.0  0.000000e+00     0.000000
# NUMBER OF MOTORIST INJURED     7659.0  2.875049e-01     0.692545
# NUMBER OF MOTORIST KILLED      7659.0  9.139574e-04     0.030220
# COLLISION_ID                   7659.0  4.495510e+06  2338.111464
#
#                                         min           25%           50%  \
# ZIP CODE                       1.000000e+04  1.045900e+04  1.120900e+04
# LATITUDE                       0.000000e+00  4.066508e+01  4.071251e+01
# LONGITUDE                     -7.424998e+01 -7.396037e+01 -7.391731e+01
# NUMBER OF PERSONS INJURED      0.000000e+00  0.000000e+00  0.000000e+00
# NUMBER OF PERSONS KILLED       0.000000e+00  0.000000e+00  0.000000e+00
# NUMBER OF PEDESTRIANS INJURED  0.000000e+00  0.000000e+00  0.000000e+00
# NUMBER OF PEDESTRIANS KILLED   0.000000e+00  0.000000e+00  0.000000e+00
# NUMBER OF CYCLIST INJURED      0.000000e+00  0.000000e+00  0.000000e+00
# NUMBER OF CYCLIST KILLED       0.000000e+00  0.000000e+00  0.000000e+00
# NUMBER OF MOTORIST INJURED     0.000000e+00  0.000000e+00  0.000000e+00
# NUMBER OF MOTORIST KILLED      0.000000e+00  0.000000e+00  0.000000e+00
# COLLISION_ID                   4.491064e+06  4.493532e+06  4.495533e+06
#
#                                         75%           max
# ZIP CODE                       1.135400e+04  1.169700e+04
# LATITUDE                       4.078696e+01  4.090921e+01
# LONGITUDE                     -7.386227e+01  0.000000e+00
# NUMBER OF PERSONS INJURED      1.000000e+00  8.000000e+00
# NUMBER OF PERSONS KILLED       0.000000e+00  1.000000e+00
# NUMBER OF PEDESTRIANS INJURED  0.000000e+00  3.000000e+00
# NUMBER OF PEDESTRIANS KILLED   0.000000e+00  1.000000e+00
# NUMBER OF CYCLIST INJURED      0.000000e+00  2.000000e+00
# NUMBER OF CYCLIST KILLED       0.000000e+00  0.000000e+00
# NUMBER OF MOTORIST INJURED     0.000000e+00  8.000000e+00
# NUMBER OF MOTORIST KILLED      0.000000e+00  1.000000e+00
# COLLISION_ID                   4.497480e+06  4.500594e+06

# %% [markdown]
# Frequency table:

# %%
pd.crosstab(index=nyc_crash["BOROUGH"], columns = "freq")
# Out:
# col_0          freq
# BOROUGH
# BRONX           948
# BROOKLYN       1744
# MANHATTAN       737
# QUEENS         1393
# STATEN ISLAND   203

# %% [markdown]
# ## Subsetting
#
# Selection by row:

# %%
brooklyn_crash = nyc_crash[nyc_crash["BOROUGH"] == "BROOKLYN"]
bronx_crash    = nyc_crash[nyc_crash["BOROUGH"] == "BRONX"]

# %% [markdown]
# Selection by column:

# %%
bronx_crash[["CRASH DATE", "CRASH TIME"]]
# Out:
#       CRASH DATE CRASH TIME
# 10    01/01/2022      16:40
# 18    01/01/2022      15:19
# 19    01/01/2022      15:00
# 22    01/01/2022      18:21
# 29    01/01/2022       1:50
# ...          ...        ...
# 7628  01/31/2022      10:32
# 7642  01/31/2022      16:00
# 7643  01/31/2022       4:54
# 7646  01/31/2022      14:58
# 7657  01/31/2022       6:50
#
# [948 rows x 2 columns]

# %% [markdown]
# By both

# %%
bronx_crash.iloc[0:9, 0:2]
# Out:
#      CRASH DATE CRASH TIME
# 10   01/01/2022      16:40
# 18   01/01/2022      15:19
# 19   01/01/2022      15:00
# 22   01/01/2022      18:21
# 29   01/01/2022       1:50
# 55   01/01/2022      22:45
# 76   01/01/2022       0:45
# 79   01/01/2022       5:55
# 108  01/01/2022       9:21

# %% [markdown]
# ## Creating new columns
#
# Convert the time string to numeric for later processing:

# %%
nyc_crash["time"] = [x.split(":")[0] for x in nyc_crash["CRASH TIME"]]
nyc_crash["time"] = [int(x) for x in nyc_crash["time"]]

import matplotlib.pyplot as plt
plt.hist(nyc_crash["time"])
# Out:
# (array([ 666.,  326.,  453., 1109.,  682.,  690., 1371.,  898.,  666.,
#          798.]),
#  array([ 0. ,  2.3,  4.6,  6.9,  9.2, 11.5, 13.8, 16.1, 18.4, 20.7, 23. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Reshape
#
# Sort table rows

# %%
nyc_crash.sort_values(by="time").head()
# Out:
#       CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 6873  01/28/2022       0:42       NaN       NaN        NaN        NaN
# 2140  01/09/2022       0:30       NaN       NaN  40.709633 -73.767815
# 5036  01/21/2022       0:45  BROOKLYN   11238.0  40.681780 -73.958740
# 5026  01/21/2022       0:34       NaN       NaN  40.741447 -73.846030
# 5016  01/21/2022       0:15  BROOKLYN   11215.0  40.660576 -73.990650
#
#                      LOCATION      ON STREET NAME   CROSS STREET NAME  \
# 6873                      NaN    ROOSEVELT AVENUE  SUBWAY QUEENS YARD
# 2140  (40.709633, -73.767815)       HOLLIS AVENUE           99 AVENUE
# 5036    (40.68178, -73.95874)                 NaN                 NaN
# 5026   (40.741447, -73.84603)  GRAND CENTRAL PKWY                 NaN
# 5016   (40.660576, -73.99065)            6 AVENUE           20 STREET
#
#               OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 3  \
# 6873                      NaN  ...                            NaN
# 2140                      NaN  ...                            NaN
# 5036  1079      FULTON STREET  ...                            NaN
# 5026                      NaN  ...                            NaN
# 5016                      NaN  ...                            NaN
#
#       CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 6873                            NaN                            NaN
# 2140                            NaN                            NaN
# 5036                            NaN                            NaN
# 5026                            NaN                            NaN
# 5016                            NaN                            NaN
#
#       COLLISION_ID                  VEHICLE TYPE CODE 1  \
# 6873       4498387                                 Bike
# 2140       4493304  Station Wagon/Sport Utility Vehicle
# 5036       4496106                                Sedan
# 5026       4496199  Station Wagon/Sport Utility Vehicle
# 5016       4496310                                Sedan
#
#                       VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3  \
# 6873                                  NaN                  NaN
# 2140  Station Wagon/Sport Utility Vehicle                  NaN
# 5036  Station Wagon/Sport Utility Vehicle                  NaN
# 5026                                  NaN                  NaN
# 5016  Station Wagon/Sport Utility Vehicle                  NaN
#
#       VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5 time
# 6873                  NaN                 NaN    0
# 2140                  NaN                 NaN    0
# 5036                  NaN                 NaN    0
# 5026                  NaN                 NaN    0
# 5016                  NaN                 NaN    0
#
# [5 rows x 30 columns]

# %% [markdown]
# Pivot table (long to wide)

# %%
nyc_crash.pivot_table(
    values  = ["LATITUDE", "LONGITUDE"],
	index   = "BOROUGH",
	aggfunc = "mean",
	margins = True)
# Out:
#                 LATITUDE  LONGITUDE
# BOROUGH
# BRONX          40.715739 -73.639080
# BROOKLYN       40.562493 -73.774724
# MANHATTAN      40.716458 -73.865181
# QUEENS         40.597138 -73.613842
# STATEN ISLAND  39.967678 -72.991762
# All            40.599550 -73.686697

# %% [markdown]
# Melting (wide to long)
#
# ## Combining
#
# Row bind

# %%
pd.concat([bronx_crash, brooklyn_crash], axis = 0).head(5)
# Out:
#     CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 10  01/01/2022      16:40   BRONX   10454.0  40.806107 -73.917990
# 18  01/01/2022      15:19   BRONX   10456.0  40.833750 -73.900490
# 19  01/01/2022      15:00   BRONX   10453.0  40.858790 -73.907364
# 22  01/01/2022      18:21   BRONX   10466.0  40.890648 -73.848750
# 29  01/01/2022       1:50   BRONX   10466.0  40.895718 -73.849525
#
#                    LOCATION   ON STREET NAME CROSS STREET NAME  \
# 10   (40.806107, -73.91799)              NaN               NaN
# 18    (40.83375, -73.90049)              NaN               NaN
# 19   (40.85879, -73.907364)  AQUEDUCT AVENUE    BUCHANAN PLACE
# 22   (40.890648, -73.84875)  EAST 233 STREET    GUNTHER AVENUE
# 29  (40.895718, -73.849525)    PITMAN AVENUE    WICKHAM AVENUE
#
#               OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 10  520       EAST 137 STREET  ...                    Unspecified
# 18  1342      FRANKLIN AVENUE  ...                            NaN
# 19                        NaN  ...                    Unspecified
# 22                        NaN  ...                    Unspecified
# 29                        NaN  ...                    Unspecified
#
#     CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 10                            NaN                            NaN
# 18                            NaN                            NaN
# 19                            NaN                            NaN
# 22                            NaN                            NaN
# 29                            NaN                            NaN
#
#     CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 10                            NaN       4491478
# 18                            NaN       4491440
# 19                            NaN       4491694
# 22                            NaN       4491488
# 29                            NaN       4491166
#
#                     VEHICLE TYPE CODE 1                  VEHICLE TYPE CODE 2  \
# 10                                Sedan                                Sedan
# 18                                 Taxi                                  NaN
# 19  Station Wagon/Sport Utility Vehicle                                  NaN
# 22                                Sedan  Station Wagon/Sport Utility Vehicle
# 29  Station Wagon/Sport Utility Vehicle                                Sedan
#
#     VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 10                  NaN                 NaN                 NaN
# 18                  NaN                 NaN                 NaN
# 19                  NaN                 NaN                 NaN
# 22                  NaN                 NaN                 NaN
# 29                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# Also can use `append()` method.

# %%
bronx_crash.append(brooklyn_crash).tail(5)
# Out:
# /tmp/ipykernel_1826/939351689.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bronx_crash.append(brooklyn_crash).tail(5)
#       CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 7645  01/31/2022      12:00  BROOKLYN   11220.0  40.640630 -74.025734
# 7650  01/31/2022       8:30  BROOKLYN   11216.0        NaN        NaN
# 7652  01/31/2022      10:12  BROOKLYN   11212.0  40.664436 -73.922100
# 7655  01/31/2022      21:50  BROOKLYN   11217.0  40.675250 -73.973350
# 7656  01/31/2022       9:40  BROOKLYN   11249.0  40.701130 -73.960870
#
#                     LOCATION ON STREET NAME         CROSS STREET NAME  \
# 7645  (40.64063, -74.025734)      65 STREET                  2 AVENUE
# 7650                     NaN            NaN                       NaN
# 7652   (40.664436, -73.9221)            NaN                       NaN
# 7655   (40.67525, -73.97335)            NaN                       NaN
# 7656   (40.70113, -73.96087)   WYTHE AVENUE  WILLIAMSBURG STREET EAST
#
#               OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 7645                      NaN  ...                    Unspecified
# 7650   486       GATES AVENUE  ...                    Unspecified
# 7652   699       RALPH AVENUE  ...                    Unspecified
# 7655  209       LINCOLN PLACE  ...                    Unspecified
# 7656                      NaN  ...                    Unspecified
#
#       CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 7645                            NaN                            NaN
# 7650                            NaN                            NaN
# 7652                            NaN                            NaN
# 7655                            NaN                            NaN
# 7656                            NaN                            NaN
#
#       CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 7645                            NaN       4499700
# 7650                            NaN       4500316
# 7652                            NaN       4500537
# 7655                            NaN       4500477
# 7656                            NaN       4500516
#
#                       VEHICLE TYPE CODE 1  \
# 7645  Station Wagon/Sport Utility Vehicle
# 7650                                Sedan
# 7652  Station Wagon/Sport Utility Vehicle
# 7655                                Sedan
# 7656  Station Wagon/Sport Utility Vehicle
#
#                       VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3  \
# 7645  Station Wagon/Sport Utility Vehicle                  NaN
# 7650  Station Wagon/Sport Utility Vehicle                  NaN
# 7652                           Motorcycle                  NaN
# 7655                                  NaN                  NaN
# 7656                            Box Truck                  NaN
#
#      VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 7645                 NaN                 NaN
# 7650                 NaN                 NaN
# 7652                 NaN                 NaN
# 7655                 NaN                 NaN
# 7656                 NaN                 NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# Column bind
